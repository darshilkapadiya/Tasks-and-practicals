# %%
#def calc():   
import tkinter
import tkinter.messagebox as msg_box

gui= tkinter.Tk()

gui.geometry("300x300")

gui.title("Calculater")

inp = tkinter.Entry(gui,width=50,textvariable=v)                    
inp.grid(row=0,column=1)


    
def o():
    inp.insert(49,"1")    
def t():
    inp.insert(49,"2")
def th():
    inp.insert(49,"3")
def f():
    inp.insert(49,"4")
def fi():
    inp.insert(49,"5")
def s():
    inp.insert(49,"6")
def se():
    inp.insert(49,"7")
def e():
    inp.insert(49,"8")
def n():
    inp.insert(49,"9")
def z():
    inp.insert(49,"0")
def cl():
    inp.delete(0)
def a():
    inp.insert(49,"+")
def su():
    inp.insert(49,"-")
def m():
    inp.insert(49,"*")
def d():
    inp.insert(49,"/")
def mo():
    inp.insert(49,"%")
def equal():
    ope = inp.get()
    if "+" in ope:
        l = ope.split("+")
        a = l[0]
        b = l[1]
        c = int(a)+int(b)
        inp.delete(0,50)
        inp.insert(0,c)
    elif "-" in ope:
        l = ope.split("-")
        a = l[0]
        b = l[1]
        c = int(a)-int(b)
        inp.delete(0,50)
        inp.insert(0,c)
    elif "*" in ope:
        l = ope.split("*")
        a = l[0]
        b = l[1]
        c = int(a)*int(b)
        inp.delete(0,50)
        inp.insert(0,c)
    elif "/" in ope:
        l = ope.split("/")
        a = l[0]
        b = l[1]
        c = int(a)/int(b)
        inp.delete(0,50)
        inp.insert(0,c)
    elif "%" in ope:
        l = ope.split("%")
        a = l[0]
        b = l[1]
        c = int(a)%int(b)
        inp.delete(0,50)
        inp.insert(0,c)
    else:
        inp.delete(0,50)
        inp.insert(0,"Invalid input")
one = tkinter.Button(gui,text="        1      ",height=2,command=o)
one.grid(row=3,column=0)
one.place(x=2,y=30)

two = tkinter.Button(gui,text="        2      ",height=2,command=t)
#two.grid(row=3,column=0)
two.place(x=70,y=30)

three = tkinter.Button(gui,text="        3      ",height=2,command=th)
three.place(x=140,y=30)

add = tkinter.Button(gui,text="        +      ",height=2,command=a)
add.place(x=220,y=30)

four = tkinter.Button(gui,text="        4      ",height=2,command=f)
four.place(x=2,y=80) 

five = tkinter.Button(gui,text="        5      ",height=2,command=fi)
five.place(x=70,y=80)

six = tkinter.Button(gui,text="        6      ",height=2,command=s)
six.place(x=140,y=80)

sub = tkinter.Button(gui,text="        -      ",height=2,command=su)
sub.place(x=220,y=80)

seven = tkinter.Button(gui,text="        7      ",height=2,command=se)
seven.place(x=2,y=120) 

eight = tkinter.Button(gui,text="        8      ",height=2,command=e)
eight.place(x=70,y=120)

nine = tkinter.Button(gui,text="        9      ",height=2,command=n)
nine.place(x=140,y=120)

mul = tkinter.Button(gui,text="        *      ",height=2,command=m)
mul.place(x=220,y=120)

zero = tkinter.Button(gui,text="        0      ",height=2,command=z)
zero.place(x=2,y=170) 

cl = tkinter.Button(gui,text="      clear    ",height=2,command=cl)
cl.place(x=70,y=170)

mod = tkinter.Button(gui,text="        %      ",height=2,command=mo)
mod.place(x=140,y=170)

div = tkinter.Button(gui,text="        /      ",height=2,command=d)
div.place(x=220,y=170)

eq = tkinter.Button(gui,text="        =      ",height=2,command=equal)
eq.place(x=2,y=220)

gui.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-0dd4c90d8c0e> in <module>()
#       3 import tkinter.messagebox as msg_box
#       4
# ----> 5 gui= tkinter.Tk()
#       6
#       7 gui.geometry("300x300")
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
