# %%
class Bank:
    def __init__(self):
        self.name = 'Darshil'
        self.__acc_no = '33xx44xx55'
        self.__pin = '30721'
        self.__mobile = '78xx34x55'
        self._Balance = '4000000'

    def show_all_details(self):
        print("Name->",self.name)
        print("Account number->",self.__acc_no)
        print("Pin no->",self.__pin)
        print("Mobile number->",self.__mobile)
        print("Available Balance->",self._Balance)
        
    def display_details(self):
        print("Name->",self.name)
        print("Available Balance->",self._Balance)
acc_num = input("Enter Your account number")
b = Bank()
if acc_num == '33xx44xx55':
    b.show_all_details()
else:
    b.display_details()
# Out:
# Enter Your account number33xx44xx55
# Name-> Darshil
# Account number-> 33xx44xx55
# Pin no-> 30721
# Mobile number-> 78xx34x55
# Available Balance-> 4000000
